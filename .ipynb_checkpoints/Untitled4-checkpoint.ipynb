# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

im = np.zeros((2, 3))
im[0,1] = 255
print(im)

imshow(im)
plt.axis('off')
plt.show()
# Out:
# [[  0. 255.   0.]
#  [  0.   0.   0.]]
